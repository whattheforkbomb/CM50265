# %% [markdown]
# # Age Estimation and Gender Classification
#
# In this assignment, you will train CNN models to estimate a person's age and gender by given a face image. Please read carefully all the instructions before you start to write your code.
#
# **Your tasks**
#
# You need train two CNN models:
# - one is defined by you with a few restrictions and be trained from scratch, save it as `age_gender_A.h5`
# - the other is to finetune a pretrained model, save it as `age_gender_B.h5`
#
# **Dataset**
#
# Your models will be trained and validated on a folder `train_val/` containing 5,000 labeled face images (size: 128 x 128), originated from the UTKFace dataset. During marking, your code will be tested on unseen test data.
#
# **Performance metric**
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy
#
# **Please use the GPU time wisely.**
#
# Just be aware that there is some limit of free GPU usage (It is said the users can use up to 12 hours in row. But many people found they reached its limit far less than 12 hours.). Therefore, I would give you three suggestions to mimimise the risk of reaching the limit.
#
# 1. Make sure you have a stable internet connection.
# 2. Double check all the hyperparameters are good before you start to train the model.
# 3. According to my experience, each model should be trained in less than 2 hours. If much longer than that, you'd better consider adjusting the architecture.

# %%
import tensorflow as tf
import numpy as np
import tensorflow.keras as keras
import cv2
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from os import listdir
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers

image_width = image_height = 128
image_channels = 3 # RGB
data_frame_labels = ['Age', 'Gender', 'Filenames']

# %% [markdown]
# ## Setting Up: Mount the google drive
# Mount your google drive to the notebook.
#
# Also don't forget to **enable GPU** before your training.

# %%
#
# Add your code here
#
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
content_dir = "/content/drive/MyDrive/ML2CW1/"

# Load data locally
# content_dir = '/mnt/g/My Drive/'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       1 #
#       2 # Add your code here
#       3 #
# ----> 4 from google.colab import drive
#       5 drive.mount('/content/drive', force_remount = True)
#       6 content_dir = "/content/drive/MyDrive/ML2CW1/"
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
content_dir = "/home/daniel/ML1Labs/ML2/CW1/"
image_dir = content_dir + "train_val/"
file_names = listdir(image_dir)

image_paths = list(map(lambda x : image_dir + x, file_names))

labels = []
for name in file_names:
  label = name.split("_")[:2]
  labels.append(label)

# %% [markdown]
# ## Visualize a few photos
# It is always benificial to know your data well before you start. Here display a few (at least 20) images together with its corresponding age and gender from the `train_val/` folder to have a first impression of the dataset. You may also check what the size of the images are.

# %%
imgs_to_show = []
num_images = 20

random_image_paths = random.sample(image_paths, num_images)

for i in range(num_images):
  imgs_to_show.append(mpimg.imread(random_image_paths[i]))

axes=[]

for i in range(20):
  image = imgs_to_show[i]
  label = random_image_paths[i].split("/")[-1].split("_")[:2]
  fig = plt.figure()
  plt.xlabel("Age: " + label[0] + " Gender: " + label[1])
  plt.imshow(image)

plt.show()

# %% [markdown]
# ## Rearrange the dataset
# You may do any arrangement for the dataset to suit your later process, such as splitting into training set and validation set, saving the gender labels and age some how, and so on.

# %%
#
# Add your code here
#
import pandas as pd

records = []
for l_age, l_gender in labels:
  records.append((int(l_age), int(l_gender)))
df = pd.DataFrame(records)
df[data_frame_labels[-1]] = image_paths
df.columns = data_frame_labels

# %% [markdown]
# ## STEP1: Data pre-processing
# Now you need do some pre-processing before feeding data into a CNN network. You may consider:
#
# 1.	Rescale the pixel values (integers between 0 and 255) to [0,1]. **You must do this rescaling.** Otherwise the testing performance will be affected significantly, as the test images will be rescaling in this way.
# 2.	Data augmentation.
#
# **Don't rescale the age to [0,1].** Otherwise the testing performance will be affected significantly, as the original age is used in the testing stage.

# %%
#
# Add your code here
#

image_datagen = ImageDataGenerator(rescale=1./255, rotation_range=20, zoom_range=0.1, horizontal_flip=True, validation_split = 0.2)
train_generator = image_datagen.flow_from_dataframe(df, x_col=data_frame_labels[-1], y_col=data_frame_labels[:-1], target_size=(image_width,image_height), color_mode='rgb', class_mode='multi_output', subset='training', batch_size=32)
validation_generator = image_datagen.flow_from_dataframe(df, x_col=data_frame_labels[-1], y_col=data_frame_labels[:-1], target_size=(image_width,image_height), color_mode='rgb', class_mode='multi_output', subset='validation', batch_size=32)
# Out:
# Found 4000 validated image filenames.
# Found 1000 validated image filenames.

# %% [markdown]
# ## STEP2A: Build your own CNN network
# Define your own CNN for classifying the gender and predicting the age. Though there are two tasks, you need **only one CNN model, but with two outputs** - you may search online for solution.
#
# There are a few restrictions about your network as follows.
# 1.	The input size must be 128 x 128 x 3, which means you **should not resize** the original images. This is because my test code relies on this particular input size. Any other size will cause problem in the testing stage.
# 2.  Please treat the gender classification as a binary problem, i.e., **the output layer for the gender branch has only 1 unit**, instead of 2 (though it is correct to treat the gender classification as a mutli-class problem where class number is 2, the last layer has 2 units). This is because my test code only works for the 1-unit-last-layer gender branch setting.
# 3.	The size of feature maps being fed to the first fully connected layer must be less than 10 x 10, while there is no number limitation about the depth.
# 4.	You may choose any techniques for preventing overfitting.
#
# In the end of the cell, use `modelA.summary()` to output the model architecture. You may also use `plot_model()` to visualize its architecture.

# %%
#
# Add your code here
#

######################################################
##                                                  ##
##    Model Creation With Tuned Hyper-Parameters    ##
##                                                  ##
######################################################

def create_modelA():
  inputs = keras.Input((image_width, image_height, image_channels))
  common_layers = create_modelA_common_layers(inputs)
  
  gender_branch = create_gender_branch(common_layers)
  age_branch = create_age_branch(common_layers)

  # Creating 1 model w/ two branches per https://pyimagesearch.com/2018/06/04/keras-multiple-outputs-and-multiple-losses/
  return keras.Model(inputs=inputs, outputs=[age_branch, gender_branch], name="ModelA")

def create_modelA_common_layers(inputs):
    common_layers = layers.Conv2D(64, (3, 3), activation='relu')(inputs)
    common_layers = layers.Conv2D(64, (3, 3), activation='relu')(common_layers)
    common_layers = layers.MaxPooling2D((2,2))(common_layers)
    common_layers = layers.BatchNormalization(axis = 3)(common_layers)
  
    common_layers = layers.Conv2D(128, (3, 3), activation='relu')(common_layers)
    common_layers = layers.MaxPooling2D((2,2))(common_layers)

    return common_layers

def create_gender_branch(inputs):    
    gender_branch = layers.Conv2D(64, (3, 3), activation='relu')(inputs)
    gender_branch = layers.MaxPooling2D((2,2))(gender_branch)
    gender_branch = layers.BatchNormalization()(gender_branch)
    
    gender_branch = layers.Conv2D(128, (2, 2), activation='relu')(gender_branch)
    gender_branch = layers.MaxPooling2D((2,2))(gender_branch)
    gender_branch = layers.BatchNormalization()(gender_branch)

    gender_branch = layers.Conv2D(64, (2, 2), activation='relu')(gender_branch) # depth determined by hyper-param-tuning # hp.Choice('gender_cnn_feature_depth', values=[1, 32, 64, 128])
    gender_branch = layers.Flatten()(gender_branch)

    gender_dropout = 0.2 # dropout rate determined by hyper-param-tuning # hp.Choice('gender_dropout_rate', values=[5e-2, 1e-1, 2e-1])
    gender_regularisation = 0.01 # regularisation factor determined by hyper-param-tuning # hp.Choice('gender_regularisation', values=[1e-2, 2e-2, 5e-2])
    
    gender_branch = layers.Dropout(gender_dropout)(gender_branch)
    gender_branch = layers.Dense(128, activation='relu', activity_regularizer=tf.keras.regularizers.l2(gender_regularisation))(gender_branch)
    gender_branch = layers.Dropout(gender_dropout)(gender_branch)
    gender_branch = layers.Dense(16, activation='relu', activity_regularizer=tf.keras.regularizers.l2(gender_regularisation))(gender_branch)
    gender_branch = layers.Dropout(gender_dropout)(gender_branch)

    gender_branch = layers.Dense(1, activation='sigmoid', activity_regularizer=tf.keras.regularizers.l2(gender_regularisation), name='gender_output')(gender_branch)

    return gender_branch

def create_age_branch(inputs):
    age_branch = layers.Conv2D(64, (3, 3), activation='relu')(inputs)
    age_branch = layers.MaxPooling2D((2,2))(age_branch)
    age_branch = layers.BatchNormalization(axis = 3)(age_branch)
    
    age_branch = layers.Conv2D(128, (2, 2), activation='relu')(age_branch)
    age_branch = layers.MaxPooling2D((2,2))(age_branch)
    age_branch = layers.BatchNormalization(axis = 3)(age_branch)
    
    age_branch = layers.Conv2D(128, (2, 2), activation='relu')(age_branch) # depth determined by hyper-param-tuning # hp.Choice('age_cnn_feature_depth', values=[1, 32, 64, 128])
    age_branch = layers.Flatten()(age_branch)
    
    age_dropout = 0.05 # dropout rate determined by hyper-param-tuning # hp.Choice('age_dropout_rate', values=[5e-2, 1e-1, 2e-1])
    age_regularisation = 0.01 # regularisation factor determined by hyper-param-tuning # hp.Choice('age_regularisation', values=[1e-2, 2e-2, 5e-2])

    age_branch = layers.Dropout(age_dropout)(age_branch)
    age_branch = layers.Dense(128, activation='relu', activity_regularizer=tf.keras.regularizers.l2(age_regularisation))(age_branch)
    age_branch = layers.Dropout(age_dropout)(age_branch)
    age_branch = layers.Dense(16, activation='relu', activity_regularizer=tf.keras.regularizers.l2(age_regularisation))(age_branch)
    age_branch = layers.Dropout(age_dropout)(age_branch)
    
    age_branch = layers.Dense(1, activation='relu',activity_regularizer=tf.keras.regularizers.l2(age_regularisation), name='age_output')(age_branch)

    return age_branch

modelA = create_modelA()

modelA.summary()
from keras.utils.vis_utils import plot_model
plot_model(modelA, show_shapes=True)


######################################
##                                  ##
##   Hyper-Parameter Tuning Logic   ##
##    Kept for reference but no     ##
##    longer needed to build the    ##
##               model              ##
##                                  ##
######################################

# !pip install -q -U keras-tuner
#
# import keras_tuner as kt
#
# def modelA_builder(hp: kt.HyperParameters):
#   gender_sigmoid = hp.Boolean('gender_sigmoid')
#   def create_modelA(hp: kt.HyperParameters):
#     greyscale = hp.Choice('use_greyscale', values=[0,1,2]) # 0 - no grescale, 
#     inputs = keras.Input((image_width, image_height, image_channels))
#
#     if (greyscale == 2): # only apply greyscale to gender branch 
#       gender_inputs = layers.Lambda(lambda c: tf.image.rgb_to_grayscale(c))(inputs)
#       gender_branch = create_modelA_common_layers(gender_inputs)
#       gender_branch = create_gender_branch(gender_branch, hp)
#
#       age_branch = create_modelA_common_layers(inputs)
#       age_branch = create_age_branch(age_branch, hp)
#     else: # greyscale for both or neither branch
#       greyscale_layer = layers.Lambda(lambda c: tf.image.rgb_to_grayscale(c))(inputs) if greyscale == 1 else inputs
#       common_layers = create_modelA_common_layers(greyscale_layer)
#       gender_branch = create_gender_branch(common_layers, hp)
#       age_branch = create_age_branch(common_layers, hp)
#
#     # Creating 1 model w/ two branches per https://pyimagesearch.com/2018/06/04/keras-multiple-outputs-and-multiple-losses/
#     return keras.Model(inputs=inputs, outputs=[age_branch, gender_branch], name="ModelA")
#
#   def create_modelA_common_layers(inputs):
#       common_layers = layers.Conv2D(64, (3, 3), activation='relu')(inputs) # 124, 124, 512
#       common_layers = layers.Conv2D(64, (3, 3), activation='relu')(common_layers)
#       common_layers = layers.MaxPooling2D((2,2))(common_layers) # 50, 50, 1024
#       common_layers = layers.BatchNormalization(axis = 3)(common_layers)
#     
#       common_layers = layers.Conv2D(128, (3, 3), activation='relu')(common_layers) # 124, 124, 512
#       common_layers = layers.MaxPooling2D((2,2))(common_layers) # 50, 50, 1024
#
#       return common_layers
#
#   def create_gender_branch(inputs, hp: kt.HyperParameters):    
#       gender_branch = layers.Conv2D(64, (3, 3), activation='relu')(inputs)
#       gender_branch = layers.MaxPooling2D((2,2))(gender_branch) # 50, 50, 1024
#       gender_branch = layers.BatchNormalization()(gender_branch)
#      
#       gender_branch = layers.Conv2D(128, (2, 2), activation='relu')(gender_branch)
#       gender_branch = layers.MaxPooling2D((2,2))(gender_branch) # 50, 50, 1024
#       gender_branch = layers.BatchNormalization()(gender_branch)
#
#       gender_branch = layers.Conv2D(hp.Choice('gender_cnn_feature_depth', values=[1, 32, 64, 128]), (2, 2), activation='relu')(gender_branch)
#       gender_branch = layers.Flatten()(gender_branch)
#
#       gender_dropout = hp.Choice('gender_dropout_rate', values=[5e-2, 1e-1, 2e-1])
#       gender_regularisation = hp.Choice('gender_regularisation', values=[1e-2, 2e-2, 5e-2])
#      
#       gender_branch = layers.Dropout(gender_dropout)(gender_branch)
#       gender_branch = layers.Dense(128, activation='relu', activity_regularizer=tf.keras.regularizers.l2(gender_regularisation))(gender_branch)
#       gender_branch = layers.Dropout(gender_dropout)(gender_branch)
#       gender_branch = layers.Dense(16, activation='relu', activity_regularizer=tf.keras.regularizers.l2(gender_regularisation))(gender_branch)
#       gender_branch = layers.Dropout(gender_dropout)(gender_branch)
#
#       if gender_sigmoid:
#         gender_branch = layers.Dense(1, activation='sigmoid', name='gender_output')(gender_branch)
#       else:
#         gender_branch = layers.Dense(1, name='gender_output')(gender_branch)
#
#       return gender_branch
#
#   def create_age_branch(inputs, hp: kt.HyperParameters):
#       age_branch = layers.Conv2D(64, (3, 3), activation='relu')(inputs)
#       #age_branch = layers.Flatten()(age_branch)
#      
#       #age_branch = layers.Conv2D(64, (3, 3), activation='relu')(age_branch)
#       age_branch = layers.MaxPooling2D((2,2))(age_branch) # 50, 50, 1024
#       age_branch = layers.BatchNormalization(axis = 3)(age_branch)
#       #age_branch = layers.Flatten()(age_branch)
#     
#       age_branch = layers.Conv2D(128, (2, 2), activation='relu')(age_branch)
#       age_branch = layers.MaxPooling2D((2,2))(age_branch) # 50, 50, 1024
#       age_branch = layers.BatchNormalization(axis = 3)(age_branch)
#       # age_branch = layers.Flatten()(age_branch)
#     
#       age_branch = layers.Conv2D(hp.Choice('age_cnn_feature_depth', values=[1, 32, 64, 128]), (2, 2), activation='relu')(age_branch)
#       age_branch = layers.Flatten()(age_branch)
#   
#       age_dropout = hp.Choice('age_dropout_rate', values=[5e-2, 1e-1, 2e-1])
#       age_regularisation = hp.Choice('age_regularisation', values=[1e-2, 2e-2, 5e-2])
#
#       age_branch = layers.Dropout(age_dropout)(age_branch)
#       age_branch = layers.Dense(128, activation='relu', activity_regularizer=tf.keras.regularizers.l2(age_regularisation))(age_branch)
#       age_branch = layers.Dropout(age_dropout)(age_branch)
#       age_branch = layers.Dense(16, activation='relu', activity_regularizer=tf.keras.regularizers.l2(age_regularisation))(age_branch)
#       age_branch = layers.Dropout(age_dropout)(age_branch)
#       age_branch = layers.Dense(1, activation='relu', name='age_output')(age_branch)
#
#       return age_branch
#
#   modelA = create_modelA(hp)
#
#   losses = {
#     "age_output": keras.losses.MeanSquaredError(), # Effectively weight the loss such that larger losses are penalised more heavily
#     "gender_output": keras.losses.BinaryCrossentropy(from_logits = not gender_sigmoid)
#   }
#   loss_weight = {
#     "age_output": 1, # since using MSE, will be quite large #hp.Choice('age_loss_weight', values=[0.25, 0.5, 1.]),
#     "gender_output": 100 # since likely between 1-0, scale up to be closer to age_loss #hp.Choice('gender_loss_weight', values=[2., 4., 8.])
#   }
#
#   metrics= {
#     "age_output": keras.metrics.MeanAbsoluteError(),
#     "gender_output": keras.metrics.BinaryAccuracy()
#   }
#
#   lr_schedule = keras.optimizers.schedules.ExponentialDecay(
#       initial_learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4]),
#       decay_steps=train_generator.n*2,
#       decay_rate=0.9)
#
#   # compile model
#   modelA_compiled = modelA.compile(loss=losses, loss_weights = loss_weight, optimizer=keras.optimizers.Adam(learning_rate=lr_schedule), metrics=metrics)
#   return modelA
#
# tuner = kt.Hyperband(modelA_builder,
#                      objective=kt.Objective("val_loss", direction="min"),
#                      max_epochs=10,
#                      factor=3)
#
# tuner.search(
#     x = train_generator,
#     validation_data=validation_generator, 
#     epochs=50
# )
#
# best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
#
# print("gender_sigmoid: {}, use_greyscale: {}, gender_cnn_feature_depth: {}, gender_dropout_rate: {}, gender_regularisation: {}, age_cnn_feature_depth: {}, age_dropout_rate: {}, age_regularisation: {}, learning_rate: {}".format(best_hps.get('gender_sigmoid'), best_hps.get('use_greyscale'), best_hps.get('gender_cnn_feature_depth'), best_hps.get('gender_dropout_rate'), best_hps.get('gender_regularisation'), best_hps.get('age_cnn_feature_depth'), best_hps.get('age_dropout_rate'), best_hps.get('age_regularisation'), best_hps.get('learning_rate')))
#
# modelA_optimised = tuner.hypermodel.build(best_hps)
# modelA_optimised.summary()
# from keras.utils.vis_utils import plot_model
# plot_model(modelA_optimised, show_shapes=True)
#
# modelA_optimised_epoch_count = 50 # ?
# modelA_optimised_train_steps_per_epoch = train_generator.n // train_generator.batch_size
# modelA_optimised_val_steps_per_epoch = validation_generator.n // validation_generator.batch_size
#
# modelA_optimised.fit(
#     x = train_generator,
#     validation_data=validation_generator,
#     epochs=modelA_optimised_epoch_count,
#     steps_per_epoch=modelA_optimised_train_steps_per_epoch,
#     validation_steps=modelA_optimised_val_steps_per_epoch
# )
# Out:
# Model: "ModelA"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_15 (InputLayer)          [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_18 (Conv2D)             (None, 126, 126, 64  1792        ['input_15[0][0]']
#                                 )
#
#  conv2d_19 (Conv2D)             (None, 124, 124, 64  36928       ['conv2d_18[0][0]']
#                                 )
#
#  max_pooling2d_12 (MaxPooling2D  (None, 62, 62, 64)  0           ['conv2d_19[0][0]']
#  )
#
#  batch_normalization_10 (BatchN  (None, 62, 62, 64)  256         ['max_pooling2d_12[0][0]']
#  ormalization)
#
#  conv2d_20 (Conv2D)             (None, 60, 60, 128)  73856       ['batch_normalization_10[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 30, 30, 128)  0          ['conv2d_20[0][0]']
#  )
#
#  conv2d_24 (Conv2D)             (None, 28, 28, 64)   73792       ['max_pooling2d_13[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 28, 28, 64)   73792       ['max_pooling2d_13[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 14, 14, 64)  0           ['conv2d_24[0][0]']
#  )
#
#  max_pooling2d_14 (MaxPooling2D  (None, 14, 14, 64)  0           ['conv2d_21[0][0]']
#  )
#
#  batch_normalization_13 (BatchN  (None, 14, 14, 64)  256         ['max_pooling2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 14, 14, 64)  256         ['max_pooling2d_14[0][0]']
#  ormalization)
#
#  conv2d_25 (Conv2D)             (None, 13, 13, 128)  32896       ['batch_normalization_13[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 13, 13, 128)  32896       ['batch_normalization_11[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 6, 6, 128)   0           ['conv2d_25[0][0]']
#  )
#
#  max_pooling2d_15 (MaxPooling2D  (None, 6, 6, 128)   0           ['conv2d_22[0][0]']
#  )
#
#  batch_normalization_14 (BatchN  (None, 6, 6, 128)   512         ['max_pooling2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 6, 6, 128)   512         ['max_pooling2d_15[0][0]']
#  ormalization)
#
#  conv2d_26 (Conv2D)             (None, 5, 5, 128)    65664       ['batch_normalization_14[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 5, 5, 64)     32832       ['batch_normalization_12[0][0]']
#
#  flatten_10 (Flatten)           (None, 3200)         0           ['conv2d_26[0][0]']
#
#  flatten_9 (Flatten)            (None, 1600)         0           ['conv2d_23[0][0]']
#
#  dropout_55 (Dropout)           (None, 3200)         0           ['flatten_10[0][0]']
#
#  dropout_52 (Dropout)           (None, 1600)         0           ['flatten_9[0][0]']
#
#  dense_50 (Dense)               (None, 128)          409728      ['dropout_55[0][0]']
#
#  dense_48 (Dense)               (None, 128)          204928      ['dropout_52[0][0]']
#
#  dropout_56 (Dropout)           (None, 128)          0           ['dense_50[0][0]']
#
#  dropout_53 (Dropout)           (None, 128)          0           ['dense_48[0][0]']
#
#  dense_51 (Dense)               (None, 16)           2064        ['dropout_56[0][0]']
#
#  dense_49 (Dense)               (None, 16)           2064        ['dropout_53[0][0]']
#
#  dropout_57 (Dropout)           (None, 16)           0           ['dense_51[0][0]']
#
#  dropout_54 (Dropout)           (None, 16)           0           ['dense_49[0][0]']
#  age_output (Dense)             (None, 1)            17          ['dropout_57[0][0]']
#
#  gender_output (Dense)          (None, 1)            17          ['dropout_54[0][0]']
#
# ==================================================================================================
# Total params: 1,045,058
# Trainable params: 1,044,162
# Non-trainable params: 896
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# ## STEP3A: Compile and train your model
# Compile and train your model here.
# Save your model by `modelA.save(your_model_folder+"age_gender_A.h5")` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Save the model with `save()` instead of `save_weights()`.** This is because I will load the model by
#
# `modelA = load_model(model_folder+"age_gender_A.h5")`.

# %%
#
# Add your code here
#

losses = {
	"age_output": keras.losses.MeanSquaredError(),
  "gender_output": keras.losses.BinaryCrossentropy()
}
loss_weight = {
	"age_output": 1.0,
    "gender_output": 100.0
}

metrics= {
  "age_output": keras.metrics.MeanAbsoluteError(),
  "gender_output": keras.metrics.BinaryAccuracy()
}

lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001, # learning rate determined by hyper-param-tuning
    decay_steps=(train_generator.n // train_generator.batch_size) * 2, # decay every 2 epochs
    decay_rate=0.9)

# compile model
modelA_compiled = modelA.compile(loss=losses, loss_weights = loss_weight, optimizer=keras.optimizers.Adam(learning_rate=lr_schedule), metrics=metrics)
print("Compiling Model A")

modelA_epoch_count = 50
modelA_train_steps_per_epoch = train_generator.n // train_generator.batch_size
modelA_val_steps_per_epoch = validation_generator.n // validation_generator.batch_size

print("training steps per epoch: {}\nvalidation steps per epoch: {}".format(modelA_train_steps_per_epoch, modelA_val_steps_per_epoch))

print("Fitting Model A")
modelA_history = modelA.fit(
    x = train_generator,
    validation_data=validation_generator,
    epochs=modelA_epoch_count,
    steps_per_epoch=modelA_train_steps_per_epoch,
    validation_steps=modelA_val_steps_per_epoch
)

modelA.save(content_dir+"age_gender_A.h5")
# Out:
# Compiling Model A
# training steps per epoch: 125
# validation steps per epoch: 31
# Fitting Model A
# Epoch 1/50
# 125/125 [==============================] - 14s 106ms/step - loss: 427.2936 - age_output_loss: 326.8889 - gender_output_loss: 0.6203 - age_output_mean_absolute_error: 13.7703 - gender_output_binary_accuracy: 0.6585 - val_loss: 455.9020 - val_age_output_loss: 351.1259 - val_gender_output_loss: 0.7308 - val_age_output_mean_absolute_error: 14.1537 - val_gender_output_binary_accuracy: 0.5292
# Epoch 2/50
# 125/125 [==============================] - 12s 99ms/step - loss: 314.7116 - age_output_loss: 224.8836 - gender_output_loss: 0.5328 - age_output_mean_absolute_error: 11.4098 - gender_output_binary_accuracy: 0.7385 - val_loss: 1571.1985 - val_age_output_loss: 1368.6307 - val_gender_output_loss: 0.8775 - val_age_output_mean_absolute_error: 32.6749 - val_gender_output_binary_accuracy: 0.5282
# Epoch 3/50
# 125/125 [==============================] - 12s 96ms/step - loss: 282.1073 - age_output_loss: 197.9763 - gender_output_loss: 0.4845 - age_output_mean_absolute_error: 10.7362 - gender_output_binary_accuracy: 0.7630 - val_loss: 1681.8358 - val_age_output_loss: 1486.0060 - val_gender_output_loss: 0.7861 - val_age_output_mean_absolute_error: 34.0360 - val_gender_output_binary_accuracy: 0.5403
# Epoch 4/50
# 125/125 [==============================] - 12s 95ms/step - loss: 255.8576 - age_output_loss: 176.4183 - gender_output_loss: 0.4468 - age_output_mean_absolute_error: 10.0575 - gender_output_binary_accuracy: 0.7945 - val_loss: 245.5532 - val_age_output_loss: 181.5767 - val_gender_output_loss: 0.3717 - val_age_output_mean_absolute_error: 9.6008 - val_gender_output_binary_accuracy: 0.8125
# Epoch 5/50
# 125/125 [==============================] - 12s 99ms/step - loss: 239.4821 - age_output_loss: 162.9153 - gender_output_loss: 0.4218 - age_output_mean_absolute_error: 9.4951 - gender_output_binary_accuracy: 0.8060 - val_loss: 292.4109 - val_age_output_loss: 208.8549 - val_gender_output_loss: 0.4304 - val_age_output_mean_absolute_error: 11.2764 - val_gender_output_binary_accuracy: 0.8065
# Epoch 6/50
# 125/125 [==============================] - 13s 100ms/step - loss: 224.5287 - age_output_loss: 153.3294 - gender_output_loss: 0.3759 - age_output_mean_absolute_error: 9.2639 - gender_output_binary_accuracy: 0.8278 - val_loss: 256.3531 - val_age_output_loss: 171.0689 - val_gender_output_loss: 0.4318 - val_age_output_mean_absolute_error: 10.3790 - val_gender_output_binary_accuracy: 0.8115
# Epoch 7/50
# 125/125 [==============================] - 12s 99ms/step - loss: 207.0962 - age_output_loss: 138.0177 - gender_output_loss: 0.3612 - age_output_mean_absolute_error: 8.7334 - gender_output_binary_accuracy: 0.8380 - val_loss: 535.4531 - val_age_output_loss: 435.9207 - val_gender_output_loss: 0.4254 - val_age_output_mean_absolute_error: 18.0692 - val_gender_output_binary_accuracy: 0.8206
# Epoch 8/50
# 125/125 [==============================] - 12s 96ms/step - loss: 197.4561 - age_output_loss: 129.4719 - gender_output_loss: 0.3533 - age_output_mean_absolute_error: 8.4502 - gender_output_binary_accuracy: 0.8440 - val_loss: 372.1891 - val_age_output_loss: 298.8008 - val_gender_output_loss: 0.4405 - val_age_output_mean_absolute_error: 13.4906 - val_gender_output_binary_accuracy: 0.7843
# Epoch 9/50
# 125/125 [==============================] - 12s 95ms/step - loss: 196.3900 - age_output_loss: 130.5170 - gender_output_loss: 0.3422 - age_output_mean_absolute_error: 8.4227 - gender_output_binary_accuracy: 0.8472 - val_loss: 201.5845 - val_age_output_loss: 134.7684 - val_gender_output_loss: 0.3270 - val_age_output_mean_absolute_error: 8.9532 - val_gender_output_binary_accuracy: 0.8558
# Epoch 10/50
# 125/125 [==============================] - 12s 95ms/step - loss: 184.2728 - age_output_loss: 120.1363 - gender_output_loss: 0.3256 - age_output_mean_absolute_error: 8.1020 - gender_output_binary_accuracy: 0.8565 - val_loss: 180.0744 - val_age_output_loss: 117.4106 - val_gender_output_loss: 0.2885 - val_age_output_mean_absolute_error: 8.0542 - val_gender_output_binary_accuracy: 0.8720
# Epoch 11/50
# 125/125 [==============================] - 12s 95ms/step - loss: 178.7277 - age_output_loss: 116.7903 - gender_output_loss: 0.3100 - age_output_mean_absolute_error: 8.0431 - gender_output_binary_accuracy: 0.8662 - val_loss: 184.5868 - val_age_output_loss: 125.3827 - val_gender_output_loss: 0.3140 - val_age_output_mean_absolute_error: 8.0674 - val_gender_output_binary_accuracy: 0.8710
# Epoch 12/50
# 125/125 [==============================] - 12s 95ms/step - loss: 171.9418 - age_output_loss: 111.2941 - gender_output_loss: 0.3027 - age_output_mean_absolute_error: 7.8562 - gender_output_binary_accuracy: 0.8690 - val_loss: 198.0410 - val_age_output_loss: 143.8518 - val_gender_output_loss: 0.3002 - val_age_output_mean_absolute_error: 8.5526 - val_gender_output_binary_accuracy: 0.8639
# Epoch 13/50
# 125/125 [==============================] - 12s 96ms/step - loss: 166.5857 - age_output_loss: 107.0205 - gender_output_loss: 0.2943 - age_output_mean_absolute_error: 7.7146 - gender_output_binary_accuracy: 0.8710 - val_loss: 179.3028 - val_age_output_loss: 124.6883 - val_gender_output_loss: 0.2896 - val_age_output_mean_absolute_error: 7.7974 - val_gender_output_binary_accuracy: 0.8720
# Epoch 14/50
# 125/125 [==============================] - 11s 90ms/step - loss: 161.3321 - age_output_loss: 101.9034 - gender_output_loss: 0.2977 - age_output_mean_absolute_error: 7.4868 - gender_output_binary_accuracy: 0.8712 - val_loss: 178.6347 - val_age_output_loss: 123.7931 - val_gender_output_loss: 0.2894 - val_age_output_mean_absolute_error: 7.8874 - val_gender_output_binary_accuracy: 0.8760
# Epoch 15/50
# 125/125 [==============================] - 12s 92ms/step - loss: 155.5457 - age_output_loss: 98.9258 - gender_output_loss: 0.2730 - age_output_mean_absolute_error: 7.3937 - gender_output_binary_accuracy: 0.8838 - val_loss: 156.6523 - val_age_output_loss: 100.9720 - val_gender_output_loss: 0.2754 - val_age_output_mean_absolute_error: 7.3018 - val_gender_output_binary_accuracy: 0.8851
# Epoch 16/50
# 125/125 [==============================] - 12s 98ms/step - loss: 149.0892 - age_output_loss: 92.5859 - gender_output_loss: 0.2745 - age_output_mean_absolute_error: 7.1299 - gender_output_binary_accuracy: 0.8880 - val_loss: 181.7306 - val_age_output_loss: 118.0075 - val_gender_output_loss: 0.2940 - val_age_output_mean_absolute_error: 8.2670 - val_gender_output_binary_accuracy: 0.8649
# Epoch 17/50
# 125/125 [==============================] - 11s 91ms/step - loss: 149.9689 - age_output_loss: 94.2418 - gender_output_loss: 0.2692 - age_output_mean_absolute_error: 7.2617 - gender_output_binary_accuracy: 0.8815 - val_loss: 153.8408 - val_age_output_loss: 98.0778 - val_gender_output_loss: 0.2670 - val_age_output_mean_absolute_error: 7.2333 - val_gender_output_binary_accuracy: 0.8780
# Epoch 18/50
# 125/125 [==============================] - 12s 93ms/step - loss: 148.5644 - age_output_loss: 93.6840 - gender_output_loss: 0.2637 - age_output_mean_absolute_error: 7.1893 - gender_output_binary_accuracy: 0.8882 - val_loss: 164.0156 - val_age_output_loss: 99.1247 - val_gender_output_loss: 0.3624 - val_age_output_mean_absolute_error: 7.4781 - val_gender_output_binary_accuracy: 0.8407
# Epoch 19/50
# 125/125 [==============================] - 11s 91ms/step - loss: 136.6451 - age_output_loss: 83.1010 - gender_output_loss: 0.2520 - age_output_mean_absolute_error: 6.7728 - gender_output_binary_accuracy: 0.8900 - val_loss: 146.3097 - val_age_output_loss: 90.6259 - val_gender_output_loss: 0.2721 - val_age_output_mean_absolute_error: 6.9591 - val_gender_output_binary_accuracy: 0.8659
# Epoch 20/50
# 125/125 [==============================] - 12s 94ms/step - loss: 137.1902 - age_output_loss: 83.8584 - gender_output_loss: 0.2563 - age_output_mean_absolute_error: 6.8109 - gender_output_binary_accuracy: 0.8900 - val_loss: 156.8870 - val_age_output_loss: 105.2618 - val_gender_output_loss: 0.2619 - val_age_output_mean_absolute_error: 7.3177 - val_gender_output_binary_accuracy: 0.8810
# Epoch 21/50
# 125/125 [==============================] - 12s 96ms/step - loss: 132.5681 - age_output_loss: 80.5255 - gender_output_loss: 0.2447 - age_output_mean_absolute_error: 6.6562 - gender_output_binary_accuracy: 0.8995 - val_loss: 147.2485 - val_age_output_loss: 94.7199 - val_gender_output_loss: 0.2776 - val_age_output_mean_absolute_error: 6.8220 - val_gender_output_binary_accuracy: 0.8760
# Epoch 22/50
# 125/125 [==============================] - 12s 95ms/step - loss: 131.6618 - age_output_loss: 79.9013 - gender_output_loss: 0.2461 - age_output_mean_absolute_error: 6.6286 - gender_output_binary_accuracy: 0.8928 - val_loss: 150.4653 - val_age_output_loss: 103.3608 - val_gender_output_loss: 0.2424 - val_age_output_mean_absolute_error: 7.0691 - val_gender_output_binary_accuracy: 0.8851
# Epoch 23/50
# 125/125 [==============================] - 12s 95ms/step - loss: 128.0806 - age_output_loss: 76.8952 - gender_output_loss: 0.2410 - age_output_mean_absolute_error: 6.5449 - gender_output_binary_accuracy: 0.9015 - val_loss: 150.5655 - val_age_output_loss: 97.8739 - val_gender_output_loss: 0.2609 - val_age_output_mean_absolute_error: 7.0659 - val_gender_output_binary_accuracy: 0.8851
# Epoch 24/50
# 125/125 [==============================] - 12s 97ms/step - loss: 127.1877 - age_output_loss: 77.2326 - gender_output_loss: 0.2315 - age_output_mean_absolute_error: 6.5726 - gender_output_binary_accuracy: 0.9038 - val_loss: 141.6159 - val_age_output_loss: 89.3611 - val_gender_output_loss: 0.2642 - val_age_output_mean_absolute_error: 6.8546 - val_gender_output_binary_accuracy: 0.8800
# Epoch 25/50
# 125/125 [==============================] - 12s 95ms/step - loss: 125.8058 - age_output_loss: 76.5571 - gender_output_loss: 0.2267 - age_output_mean_absolute_error: 6.4939 - gender_output_binary_accuracy: 0.8980 - val_loss: 134.2610 - val_age_output_loss: 82.8646 - val_gender_output_loss: 0.2666 - val_age_output_mean_absolute_error: 6.4780 - val_gender_output_binary_accuracy: 0.8841
# Epoch 26/50
# 125/125 [==============================] - 12s 96ms/step - loss: 124.0525 - age_output_loss: 73.8925 - gender_output_loss: 0.2374 - age_output_mean_absolute_error: 6.3622 - gender_output_binary_accuracy: 0.8982 - val_loss: 141.4661 - val_age_output_loss: 89.4819 - val_gender_output_loss: 0.2541 - val_age_output_mean_absolute_error: 6.8418 - val_gender_output_binary_accuracy: 0.8942
# Epoch 27/50
# 125/125 [==============================] - 13s 100ms/step - loss: 120.2698 - age_output_loss: 72.3346 - gender_output_loss: 0.2179 - age_output_mean_absolute_error: 6.3682 - gender_output_binary_accuracy: 0.9060 - val_loss: 137.0869 - val_age_output_loss: 85.1914 - val_gender_output_loss: 0.2473 - val_age_output_mean_absolute_error: 6.8057 - val_gender_output_binary_accuracy: 0.8851
# Epoch 28/50
# 125/125 [==============================] - 12s 96ms/step - loss: 119.3192 - age_output_loss: 71.2214 - gender_output_loss: 0.2197 - age_output_mean_absolute_error: 6.2477 - gender_output_binary_accuracy: 0.9095 - val_loss: 136.6443 - val_age_output_loss: 86.2277 - val_gender_output_loss: 0.2592 - val_age_output_mean_absolute_error: 6.5599 - val_gender_output_binary_accuracy: 0.8881
# Epoch 29/50
# 125/125 [==============================] - 12s 99ms/step - loss: 116.7588 - age_output_loss: 69.3209 - gender_output_loss: 0.2136 - age_output_mean_absolute_error: 6.1824 - gender_output_binary_accuracy: 0.9055 - val_loss: 137.8051 - val_age_output_loss: 88.2010 - val_gender_output_loss: 0.2548 - val_age_output_mean_absolute_error: 6.7359 - val_gender_output_binary_accuracy: 0.8871
# Epoch 30/50
# 125/125 [==============================] - 12s 99ms/step - loss: 114.4764 - age_output_loss: 67.8447 - gender_output_loss: 0.2091 - age_output_mean_absolute_error: 6.1190 - gender_output_binary_accuracy: 0.9130 - val_loss: 142.6500 - val_age_output_loss: 93.3737 - val_gender_output_loss: 0.2437 - val_age_output_mean_absolute_error: 6.9709 - val_gender_output_binary_accuracy: 0.8901
# Epoch 31/50
# 125/125 [==============================] - 12s 99ms/step - loss: 116.0776 - age_output_loss: 69.8591 - gender_output_loss: 0.2061 - age_output_mean_absolute_error: 6.2338 - gender_output_binary_accuracy: 0.9082 - val_loss: 147.5713 - val_age_output_loss: 101.3662 - val_gender_output_loss: 0.2449 - val_age_output_mean_absolute_error: 7.0681 - val_gender_output_binary_accuracy: 0.8942
# Epoch 32/50
# 125/125 [==============================] - 12s 96ms/step - loss: 115.4261 - age_output_loss: 69.7937 - gender_output_loss: 0.2008 - age_output_mean_absolute_error: 6.2033 - gender_output_binary_accuracy: 0.9160 - val_loss: 144.0829 - val_age_output_loss: 94.8763 - val_gender_output_loss: 0.2461 - val_age_output_mean_absolute_error: 6.8356 - val_gender_output_binary_accuracy: 0.8962
# Epoch 33/50
# 125/125 [==============================] - 12s 95ms/step - loss: 111.4216 - age_output_loss: 66.2630 - gender_output_loss: 0.1979 - age_output_mean_absolute_error: 6.1047 - gender_output_binary_accuracy: 0.9172 - val_loss: 139.2113 - val_age_output_loss: 86.1534 - val_gender_output_loss: 0.2745 - val_age_output_mean_absolute_error: 6.6320 - val_gender_output_binary_accuracy: 0.8710
# Epoch 34/50
# 125/125 [==============================] - 12s 95ms/step - loss: 109.5208 - age_output_loss: 64.7089 - gender_output_loss: 0.1929 - age_output_mean_absolute_error: 6.0357 - gender_output_binary_accuracy: 0.9243 - val_loss: 133.3186 - val_age_output_loss: 86.8101 - val_gender_output_loss: 0.2416 - val_age_output_mean_absolute_error: 6.6029 - val_gender_output_binary_accuracy: 0.8851
# Epoch 35/50
# 125/125 [==============================] - 12s 95ms/step - loss: 107.6814 - age_output_loss: 63.3195 - gender_output_loss: 0.1911 - age_output_mean_absolute_error: 5.9328 - gender_output_binary_accuracy: 0.9258 - val_loss: 135.1627 - val_age_output_loss: 90.6786 - val_gender_output_loss: 0.2327 - val_age_output_mean_absolute_error: 6.7099 - val_gender_output_binary_accuracy: 0.8962
# Epoch 36/50
# 125/125 [==============================] - 12s 95ms/step - loss: 106.5306 - age_output_loss: 62.2470 - gender_output_loss: 0.1929 - age_output_mean_absolute_error: 5.8962 - gender_output_binary_accuracy: 0.9210 - val_loss: 134.9978 - val_age_output_loss: 84.3511 - val_gender_output_loss: 0.2734 - val_age_output_mean_absolute_error: 6.6224 - val_gender_output_binary_accuracy: 0.8841
# Epoch 37/50
# 125/125 [==============================] - 12s 95ms/step - loss: 106.7542 - age_output_loss: 62.8437 - gender_output_loss: 0.1891 - age_output_mean_absolute_error: 5.9005 - gender_output_binary_accuracy: 0.9230 - val_loss: 133.3067 - val_age_output_loss: 82.9353 - val_gender_output_loss: 0.2482 - val_age_output_mean_absolute_error: 6.6949 - val_gender_output_binary_accuracy: 0.8891
# Epoch 38/50
# 125/125 [==============================] - 12s 97ms/step - loss: 102.0409 - age_output_loss: 58.5681 - gender_output_loss: 0.1851 - age_output_mean_absolute_error: 5.7673 - gender_output_binary_accuracy: 0.9220 - val_loss: 136.3106 - val_age_output_loss: 90.5526 - val_gender_output_loss: 0.2406 - val_age_output_mean_absolute_error: 6.7689 - val_gender_output_binary_accuracy: 0.8831
# Epoch 39/50
# 125/125 [==============================] - 12s 98ms/step - loss: 101.0495 - age_output_loss: 58.8185 - gender_output_loss: 0.1743 - age_output_mean_absolute_error: 5.7779 - gender_output_binary_accuracy: 0.9300 - val_loss: 129.5871 - val_age_output_loss: 82.0282 - val_gender_output_loss: 0.2351 - val_age_output_mean_absolute_error: 6.5868 - val_gender_output_binary_accuracy: 0.9032
# Epoch 40/50
# 125/125 [==============================] - 13s 100ms/step - loss: 104.0172 - age_output_loss: 60.7872 - gender_output_loss: 0.1848 - age_output_mean_absolute_error: 5.8520 - gender_output_binary_accuracy: 0.9277 - val_loss: 128.7963 - val_age_output_loss: 80.3502 - val_gender_output_loss: 0.2343 - val_age_output_mean_absolute_error: 6.6101 - val_gender_output_binary_accuracy: 0.8962
# Epoch 41/50
# 125/125 [==============================] - 13s 102ms/step - loss: 101.5322 - age_output_loss: 59.3144 - gender_output_loss: 0.1759 - age_output_mean_absolute_error: 5.7595 - gender_output_binary_accuracy: 0.9280 - val_loss: 134.0206 - val_age_output_loss: 86.0929 - val_gender_output_loss: 0.2506 - val_age_output_mean_absolute_error: 6.6887 - val_gender_output_binary_accuracy: 0.8921
# Epoch 42/50
# 125/125 [==============================] - 12s 94ms/step - loss: 98.8977 - age_output_loss: 57.2788 - gender_output_loss: 0.1688 - age_output_mean_absolute_error: 5.6396 - gender_output_binary_accuracy: 0.9342 - val_loss: 128.4389 - val_age_output_loss: 81.6267 - val_gender_output_loss: 0.2496 - val_age_output_mean_absolute_error: 6.3641 - val_gender_output_binary_accuracy: 0.8962
# Epoch 43/50
# 125/125 [==============================] - 12s 96ms/step - loss: 96.0912 - age_output_loss: 54.6823 - gender_output_loss: 0.1681 - age_output_mean_absolute_error: 5.5346 - gender_output_binary_accuracy: 0.9325 - val_loss: 136.5025 - val_age_output_loss: 87.9983 - val_gender_output_loss: 0.2479 - val_age_output_mean_absolute_error: 6.7025 - val_gender_output_binary_accuracy: 0.8871
# Epoch 44/50
# 125/125 [==============================] - 12s 96ms/step - loss: 98.6821 - age_output_loss: 57.1973 - gender_output_loss: 0.1701 - age_output_mean_absolute_error: 5.6659 - gender_output_binary_accuracy: 0.9283 - val_loss: 135.5643 - val_age_output_loss: 90.1144 - val_gender_output_loss: 0.2382 - val_age_output_mean_absolute_error: 6.6650 - val_gender_output_binary_accuracy: 0.8881
# Epoch 45/50
# 125/125 [==============================] - 12s 95ms/step - loss: 95.7357 - age_output_loss: 54.2976 - gender_output_loss: 0.1709 - age_output_mean_absolute_error: 5.5361 - gender_output_binary_accuracy: 0.9300 - val_loss: 126.6668 - val_age_output_loss: 80.0872 - val_gender_output_loss: 0.2297 - val_age_output_mean_absolute_error: 6.4716 - val_gender_output_binary_accuracy: 0.8952
# Epoch 46/50
# 125/125 [==============================] - 12s 95ms/step - loss: 97.5687 - age_output_loss: 56.4814 - gender_output_loss: 0.1672 - age_output_mean_absolute_error: 5.6621 - gender_output_binary_accuracy: 0.9305 - val_loss: 129.4772 - val_age_output_loss: 81.8592 - val_gender_output_loss: 0.2366 - val_age_output_mean_absolute_error: 6.5306 - val_gender_output_binary_accuracy: 0.8942
# Epoch 47/50
# 125/125 [==============================] - 12s 95ms/step - loss: 95.3502 - age_output_loss: 54.5734 - gender_output_loss: 0.1642 - age_output_mean_absolute_error: 5.5191 - gender_output_binary_accuracy: 0.9352 - val_loss: 132.8290 - val_age_output_loss: 86.8054 - val_gender_output_loss: 0.2417 - val_age_output_mean_absolute_error: 6.6565 - val_gender_output_binary_accuracy: 0.8901
# Epoch 48/50
# 125/125 [==============================] - 12s 95ms/step - loss: 95.3084 - age_output_loss: 53.9302 - gender_output_loss: 0.1720 - age_output_mean_absolute_error: 5.5167 - gender_output_binary_accuracy: 0.9298 - val_loss: 128.6174 - val_age_output_loss: 81.2490 - val_gender_output_loss: 0.2444 - val_age_output_mean_absolute_error: 6.4585 - val_gender_output_binary_accuracy: 0.8921
# Epoch 49/50
# 125/125 [==============================] - 12s 95ms/step - loss: 93.9598 - age_output_loss: 53.8998 - gender_output_loss: 0.1602 - age_output_mean_absolute_error: 5.4819 - gender_output_binary_accuracy: 0.9360 - val_loss: 129.7976 - val_age_output_loss: 85.6103 - val_gender_output_loss: 0.2266 - val_age_output_mean_absolute_error: 6.4751 - val_gender_output_binary_accuracy: 0.8942
# Epoch 50/50
# 125/125 [==============================] - 12s 94ms/step - loss: 91.9244 - age_output_loss: 52.3847 - gender_output_loss: 0.1548 - age_output_mean_absolute_error: 5.4253 - gender_output_binary_accuracy: 0.9345 - val_loss: 131.9178 - val_age_output_loss: 86.1918 - val_gender_output_loss: 0.2427 - val_age_output_mean_absolute_error: 6.5744 - val_gender_output_binary_accuracy: 0.8942

# %% [markdown]
# ## STEP4A: Draw the learning curves
# Draw four figures as follows
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
#
# Add your code here
#
epochs = np.linspace(0, modelA_epoch_count, modelA_epoch_count)

fig, (gender_loss, gender_accuracy) = plt.subplots(2, sharex=True)
fig.suptitle("Gender Learning Curves")
fig.set_size_inches(12,8)

gender_loss.set_xlabel("Epoch")
gender_loss.set_ylabel("Gender Loss")
gender_loss.plot(epochs, modelA_history.history['gender_output_loss'], label='training')
gender_loss.plot(epochs, modelA_history.history['val_gender_output_loss'], label='validation')
gender_loss.legend()

gender_accuracy.set_xlabel("Epoch")
gender_accuracy.set_ylabel("Gender Accuracy")
gender_accuracy.plot(epochs, modelA_history.history['gender_output_binary_accuracy'], label='training')
gender_accuracy.plot(epochs, modelA_history.history['val_gender_output_binary_accuracy'], label='validation')
gender_accuracy.legend()

plt.show()

fig, (age_loss, age_mae) = plt.subplots(2, sharex=True)
fig.suptitle("Age Learning Curves")
fig.set_size_inches(12,8)

age_loss.set_xlabel("Epoch")
age_loss.set_ylabel("Age Loss")
age_loss.plot(epochs, modelA_history.history['age_output_loss'], label='training')
age_loss.plot(epochs, modelA_history.history['val_age_output_loss'], label='validation')
age_loss.legend()

age_mae.set_xlabel("Epoch")
age_mae.set_ylabel("Age Mean Absolute Error (MEA)")
age_mae.plot(epochs, modelA_history.history['age_output_mean_absolute_error'], label='training')
age_mae.plot(epochs, modelA_history.history['val_age_output_mean_absolute_error'], label='validation')
age_mae.legend()

plt.show()

# %% [markdown]
# ## STEP2B: Build a CNN network based on a pre-trained model
# Choose one existing CNN architecture pre-trained on ImageNet, and fine-tune on this dataset.
#
# The same as required in Model A, **don’t resize the input image size**. **The output layer for the gender branch is set to have only 1 unit**.
#
# In the end of the cell, use `modelB.summary()` to output the model architecture. You may also use `plot_model()` to visualize its architecture.

# %%
import tensorflow.keras.applications.resnet50 as ResNet50 # quick, lighweight, and fairly accurate  

inputs_b = keras.Input((image_width, image_height, image_channels))
base_resnet50 = ResNet50.ResNet50(input_tensor=inputs_b, weights='imagenet', include_top=False)
base_resnet50.trainable = True
globalPool = layers.GlobalAveragePooling2D()(base_resnet50.output) # layers.Flatten()(base_resnet50.output)

gender_branch = layers.Dense(256, activation='relu', activity_regularizer=tf.keras.regularizers.l2(0.01))(globalPool)
gender_branch = layers.Dropout(0.2)(gender_branch)
gender_branch = layers.Dense(16, activation='relu', activity_regularizer=tf.keras.regularizers.l2(0.01))(gender_branch)
gender_branch = layers.Dropout(0.2)(gender_branch)
gender_branch = layers.Dense(1, activation = 'sigmoid', activity_regularizer=tf.keras.regularizers.l2(0.01),  name='gender_output')(gender_branch)


age_branch = layers.Dense(256, activation='relu', activity_regularizer=tf.keras.regularizers.l2(0.01))(globalPool)
age_branch = layers.Dropout(0.2)(age_branch)
age_branch = layers.Dense(16, activation='relu', activity_regularizer=tf.keras.regularizers.l2(0.01))(age_branch)
age_branch = layers.Dropout(0.2)(age_branch)
age_branch = layers.Dense(1, name='age_output', activity_regularizer=tf.keras.regularizers.l2(0.01))(age_branch)

modelB = keras.Model(inputs=base_resnet50.inputs, outputs=[age_branch, gender_branch])

modelB.summary()
from tensorflow.keras.utils import plot_model
plot_model(modelB, show_shapes=True)
# Out:
# Model: "model_10"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_16 (InputLayer)          [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 134, 134, 3)  0           ['input_16[0][0]']
#
#  conv1_conv (Conv2D)            (None, 64, 64, 64)   9472        ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 64, 64, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (Activation)        (None, 64, 64, 64)   0           ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)      (None, 66, 66, 64)   0           ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)      (None, 32, 32, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 32, 32, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 32, 32, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 32, 32, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 32, 32, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 32, 32, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 32, 32, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 32, 32, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 32, 32, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 32, 32, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 32, 32, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 32, 32, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 32, 32, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#  conv2_block3_2_conv (Conv2D)   (None, 32, 32, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 32, 32, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 32, 32, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 32, 32, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 32, 32, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 32, 32, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 32, 32, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 16, 16, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 16, 16, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 16, 16, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 16, 16, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 16, 16, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 16, 16, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 16, 16, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 16, 16, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 16, 16, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 16, 16, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 16, 16, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 16, 16, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#  conv3_block3_2_conv (Conv2D)   (None, 16, 16, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 16, 16, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 16, 16, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 16, 16, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 16, 16, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 16, 16, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 16, 16, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 16, 16, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 16, 16, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 16, 16, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 16, 16, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 16, 16, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 8, 8, 256)    131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 8, 8, 256)    590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 8, 8, 1024)   525312      ['conv3_block4_out[0][0]']
#
#  conv4_block1_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block1_2_relu[0][0]']
#
#  conv4_block1_0_bn (BatchNormal  (None, 8, 8, 1024)  4096        ['conv4_block1_0_conv[0][0]']
#  ization)
#
#  conv4_block1_3_bn (BatchNormal  (None, 8, 8, 1024)  4096        ['conv4_block1_3_conv[0][0]']
#  ization)
#
#  conv4_block1_add (Add)         (None, 8, 8, 1024)   0           ['conv4_block1_0_bn[0][0]',
#                                                                   'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 8, 8, 1024)   0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_1_conv (Conv2D)   (None, 8, 8, 256)    262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block2_1_bn[0][0]']
#  n)
#  conv4_block2_2_conv (Conv2D)   (None, 8, 8, 256)    590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block2_2_relu[0][0]']
#
#  conv4_block2_3_bn (BatchNormal  (None, 8, 8, 1024)  4096        ['conv4_block2_3_conv[0][0]']
#  ization)
#
#  conv4_block2_add (Add)         (None, 8, 8, 1024)   0           ['conv4_block1_out[0][0]',
#                                                                   'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 8, 8, 1024)   0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_1_conv (Conv2D)   (None, 8, 8, 256)    262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 8, 8, 256)    590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block3_2_relu[0][0]']
#
#  conv4_block3_3_bn (BatchNormal  (None, 8, 8, 1024)  4096        ['conv4_block3_3_conv[0][0]']
#  ization)
#
#  conv4_block3_add (Add)         (None, 8, 8, 1024)   0           ['conv4_block2_out[0][0]',
#                                                                   'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 8, 8, 1024)   0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_1_conv (Conv2D)   (None, 8, 8, 256)    262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 8, 8, 256)    590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block4_2_relu[0][0]']
#
#  conv4_block4_3_bn (BatchNormal  (None, 8, 8, 1024)  4096        ['conv4_block4_3_conv[0][0]']
#  ization)
#
#  conv4_block4_add (Add)         (None, 8, 8, 1024)   0           ['conv4_block3_out[0][0]',
#                                                                   'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 8, 8, 1024)   0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_1_conv (Conv2D)   (None, 8, 8, 256)    262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 8, 8, 256)    590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block5_2_conv[0][0]']
#  ization)
#  conv4_block5_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block5_2_relu[0][0]']
#
#  conv4_block5_3_bn (BatchNormal  (None, 8, 8, 1024)  4096        ['conv4_block5_3_conv[0][0]']
#  ization)
#
#  conv4_block5_add (Add)         (None, 8, 8, 1024)   0           ['conv4_block4_out[0][0]',
#                                                                   'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 8, 8, 1024)   0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_1_conv (Conv2D)   (None, 8, 8, 256)    262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 8, 8, 256)    590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 8, 8, 256)   1024        ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 8, 8, 256)   0           ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 8, 8, 1024)   263168      ['conv4_block6_2_relu[0][0]']
#
#  conv4_block6_3_bn (BatchNormal  (None, 8, 8, 1024)  4096        ['conv4_block6_3_conv[0][0]']
#  ization)
#
#  conv4_block6_add (Add)         (None, 8, 8, 1024)   0           ['conv4_block5_out[0][0]',
#                                                                   'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 8, 8, 1024)   0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_1_conv (Conv2D)   (None, 4, 4, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 4, 4, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 4, 4, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#  conv5_block2_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 4, 4, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 4, 4, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 4, 4, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 4, 4, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 4, 4, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 4, 4, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 4, 4, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 4, 4, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 4, 4, 2048)   0           ['conv5_block3_add[0][0]']
#
#  global_average_pooling2d_5 (Gl  (None, 2048)        0           ['conv5_block3_out[0][0]']
#  obalAveragePooling2D)
#
#  dense_54 (Dense)               (None, 256)          524544      ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dense_52 (Dense)               (None, 256)          524544      ['global_average_pooling2d_5[0][0
#                                                                  ]']
#
#  dropout_60 (Dropout)           (None, 256)          0           ['dense_54[0][0]']
#
#  dropout_58 (Dropout)           (None, 256)          0           ['dense_52[0][0]']
#
#  dense_55 (Dense)               (None, 16)           4112        ['dropout_60[0][0]']
#
#  dense_53 (Dense)               (None, 16)           4112        ['dropout_58[0][0]']
#
#  dropout_61 (Dropout)           (None, 16)           0           ['dense_55[0][0]']
#
#  dropout_59 (Dropout)           (None, 16)           0           ['dense_53[0][0]']
#
#  age_output (Dense)             (None, 1)            17          ['dropout_61[0][0]']
#
#  gender_output (Dense)          (None, 1)            17          ['dropout_59[0][0]']
#
# ==================================================================================================
# Total params: 24,645,058
# Trainable params: 24,591,938
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %% [markdown]
# ## STEP3B: Compile and train your model
# Compile and train your model here.
# Save your model to `age_gender_B.h5` after training.
#
# **DON'T use any other name for your model file.** This is because my test code relies on this particular model name. Any other file name will cause problem in the testing stage.
#
# **Also, save the model with `save()` instead of `save_weights()`.**

# %%
#
# Add your code here
#
losses = {
  "age_output": keras.losses.MeanSquaredError(),
	"gender_output": keras.losses.BinaryCrossentropy() # BinaryFocalCrossentropy(from_logits = False)
}
loss_weight = {
	"age_output": 1.0,
    "gender_output": 100.0 # 50.0
}
metrics= {
  "age_output": keras.metrics.MeanAbsoluteError(),
  "gender_output": keras.metrics.BinaryAccuracy()
}
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001, # learning rate determined by hyper-param-tuning
    decay_steps=(train_generator.n // train_generator.batch_size) * 2, # decay every 2 epochs
    decay_rate=0.9)

modelB_compiled = modelB.compile(loss=losses, loss_weights = loss_weight, optimizer=keras.optimizers.Adam(learning_rate=lr_schedule), metrics=metrics)
print("Compiling Model B")

modelB_epoch_count = 50 # ?
modelB_train_steps_per_epoch = train_generator.n // train_generator.batch_size
modelB_val_steps_per_epoch = validation_generator.n // validation_generator.batch_size

early_stop_cb = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=5,
    mode='min', restore_best_weights=True
)

modelB_history = modelB.fit(
    x=train_generator,
    validation_data=validation_generator,
    epochs=modelB_epoch_count,
    steps_per_epoch=modelB_train_steps_per_epoch,
    validation_steps=modelB_val_steps_per_epoch,
    callbacks=[early_stop_cb]
)
modelA.save(content_dir+"age_gender_B.h5")
# Out:
# Compiling Model B
# Epoch 1/50
# 125/125 [==============================] - 23s 148ms/step - loss: 474.6560 - age_output_loss: 360.5115 - gender_output_loss: 0.6119 - age_output_mean_absolute_error: 14.2211 - gender_output_binary_accuracy: 0.6735 - val_loss: 677.7138 - val_age_output_loss: 578.1781 - val_gender_output_loss: 0.8372 - val_age_output_mean_absolute_error: 18.3875 - val_gender_output_binary_accuracy: 0.5272
# Epoch 2/50
# 125/125 [==============================] - 18s 141ms/step - loss: 325.5683 - age_output_loss: 228.6319 - gender_output_loss: 0.4812 - age_output_mean_absolute_error: 11.0893 - gender_output_binary_accuracy: 0.7803 - val_loss: 683.1784 - val_age_output_loss: 600.2086 - val_gender_output_loss: 0.6919 - val_age_output_mean_absolute_error: 18.7756 - val_gender_output_binary_accuracy: 0.5272
# Epoch 3/50
# 125/125 [==============================] - 18s 142ms/step - loss: 290.6384 - age_output_loss: 205.4301 - gender_output_loss: 0.3848 - age_output_mean_absolute_error: 10.4828 - gender_output_binary_accuracy: 0.8315 - val_loss: 535.3713 - val_age_output_loss: 410.9364 - val_gender_output_loss: 0.9502 - val_age_output_mean_absolute_error: 14.7287 - val_gender_output_binary_accuracy: 0.5272
# Epoch 4/50
# 125/125 [==============================] - 18s 142ms/step - loss: 260.4905 - age_output_loss: 181.7092 - gender_output_loss: 0.3617 - age_output_mean_absolute_error: 9.8507 - gender_output_binary_accuracy: 0.8315 - val_loss: 656.4251 - val_age_output_loss: 565.2904 - val_gender_output_loss: 0.7887 - val_age_output_mean_absolute_error: 18.0751 - val_gender_output_binary_accuracy: 0.4748
# Epoch 5/50
# 125/125 [==============================] - 18s 142ms/step - loss: 241.2275 - age_output_loss: 168.0116 - gender_output_loss: 0.3260 - age_output_mean_absolute_error: 9.4273 - gender_output_binary_accuracy: 0.8540 - val_loss: 849.3966 - val_age_output_loss: 693.8391 - val_gender_output_loss: 0.7599 - val_age_output_mean_absolute_error: 22.8779 - val_gender_output_binary_accuracy: 0.5302
# Epoch 6/50
# 125/125 [==============================] - 18s 143ms/step - loss: 219.0758 - age_output_loss: 148.5958 - gender_output_loss: 0.3202 - age_output_mean_absolute_error: 8.9223 - gender_output_binary_accuracy: 0.8608 - val_loss: 344.2043 - val_age_output_loss: 249.4619 - val_gender_output_loss: 0.6162 - val_age_output_mean_absolute_error: 11.8516 - val_gender_output_binary_accuracy: 0.6452
# Epoch 7/50
# 125/125 [==============================] - 18s 142ms/step - loss: 222.3744 - age_output_loss: 157.1742 - gender_output_loss: 0.2868 - age_output_mean_absolute_error: 9.1157 - gender_output_binary_accuracy: 0.8710 - val_loss: 288.7028 - val_age_output_loss: 211.5522 - val_gender_output_loss: 0.5375 - val_age_output_mean_absolute_error: 9.9805 - val_gender_output_binary_accuracy: 0.7167
# Epoch 8/50
# 125/125 [==============================] - 18s 142ms/step - loss: 214.0783 - age_output_loss: 150.6438 - gender_output_loss: 0.2847 - age_output_mean_absolute_error: 8.9321 - gender_output_binary_accuracy: 0.8752 - val_loss: 244.4967 - val_age_output_loss: 148.9379 - val_gender_output_loss: 0.5150 - val_age_output_mean_absolute_error: 9.5545 - val_gender_output_binary_accuracy: 0.7712
# Epoch 9/50
# 125/125 [==============================] - 18s 142ms/step - loss: 203.0130 - age_output_loss: 142.2290 - gender_output_loss: 0.2629 - age_output_mean_absolute_error: 8.7431 - gender_output_binary_accuracy: 0.8810 - val_loss: 192.5240 - val_age_output_loss: 136.5605 - val_gender_output_loss: 0.3078 - val_age_output_mean_absolute_error: 8.5063 - val_gender_output_binary_accuracy: 0.8609
# Epoch 10/50
# 125/125 [==============================] - 18s 142ms/step - loss: 196.1000 - age_output_loss: 137.1377 - gender_output_loss: 0.2548 - age_output_mean_absolute_error: 8.5469 - gender_output_binary_accuracy: 0.8930 - val_loss: 337.0641 - val_age_output_loss: 291.3828 - val_gender_output_loss: 0.3051 - val_age_output_mean_absolute_error: 11.7668 - val_gender_output_binary_accuracy: 0.8558
# Epoch 11/50
# 125/125 [==============================] - 18s 142ms/step - loss: 176.9056 - age_output_loss: 120.9641 - gender_output_loss: 0.2362 - age_output_mean_absolute_error: 8.0237 - gender_output_binary_accuracy: 0.8997 - val_loss: 184.6812 - val_age_output_loss: 121.4111 - val_gender_output_loss: 0.3877 - val_age_output_mean_absolute_error: 7.3775 - val_gender_output_binary_accuracy: 0.8256
# Epoch 12/50
# 125/125 [==============================] - 18s 143ms/step - loss: 178.0356 - age_output_loss: 123.9900 - gender_output_loss: 0.2262 - age_output_mean_absolute_error: 8.0329 - gender_output_binary_accuracy: 0.9035 - val_loss: 179.5788 - val_age_output_loss: 113.6555 - val_gender_output_loss: 0.3371 - val_age_output_mean_absolute_error: 7.8253 - val_gender_output_binary_accuracy: 0.8548
# Epoch 13/50
# 125/125 [==============================] - 18s 142ms/step - loss: 165.5755 - age_output_loss: 112.1225 - gender_output_loss: 0.2228 - age_output_mean_absolute_error: 7.6891 - gender_output_binary_accuracy: 0.9005 - val_loss: 228.1305 - val_age_output_loss: 183.0798 - val_gender_output_loss: 0.2675 - val_age_output_mean_absolute_error: 9.5824 - val_gender_output_binary_accuracy: 0.8720
# Epoch 14/50
# 125/125 [==============================] - 18s 142ms/step - loss: 169.2041 - age_output_loss: 116.8788 - gender_output_loss: 0.2203 - age_output_mean_absolute_error: 7.8522 - gender_output_binary_accuracy: 0.9045 - val_loss: 154.1000 - val_age_output_loss: 97.4592 - val_gender_output_loss: 0.3040 - val_age_output_mean_absolute_error: 6.6273 - val_gender_output_binary_accuracy: 0.8700
# Epoch 15/50
# 125/125 [==============================] - 18s 143ms/step - loss: 172.6009 - age_output_loss: 123.2457 - gender_output_loss: 0.1977 - age_output_mean_absolute_error: 7.9576 - gender_output_binary_accuracy: 0.9158 - val_loss: 140.9080 - val_age_output_loss: 83.5699 - val_gender_output_loss: 0.2897 - val_age_output_mean_absolute_error: 6.3886 - val_gender_output_binary_accuracy: 0.8800
# Epoch 16/50
# 125/125 [==============================] - 18s 142ms/step - loss: 169.2117 - age_output_loss: 120.7375 - gender_output_loss: 0.1873 - age_output_mean_absolute_error: 7.9081 - gender_output_binary_accuracy: 0.9205 - val_loss: 141.1610 - val_age_output_loss: 93.3327 - val_gender_output_loss: 0.2329 - val_age_output_mean_absolute_error: 6.6021 - val_gender_output_binary_accuracy: 0.8962
# Epoch 17/50
# 125/125 [==============================] - 18s 142ms/step - loss: 158.2582 - age_output_loss: 111.7876 - gender_output_loss: 0.1747 - age_output_mean_absolute_error: 7.6567 - gender_output_binary_accuracy: 0.9247 - val_loss: 170.0179 - val_age_output_loss: 106.0039 - val_gender_output_loss: 0.2773 - val_age_output_mean_absolute_error: 7.6072 - val_gender_output_binary_accuracy: 0.8821
# Epoch 18/50
# 125/125 [==============================] - 18s 142ms/step - loss: 154.7886 - age_output_loss: 107.4545 - gender_output_loss: 0.1833 - age_output_mean_absolute_error: 7.5622 - gender_output_binary_accuracy: 0.9212 - val_loss: 145.8021 - val_age_output_loss: 92.9418 - val_gender_output_loss: 0.2777 - val_age_output_mean_absolute_error: 6.6575 - val_gender_output_binary_accuracy: 0.8649
# Epoch 19/50
# 125/125 [==============================] - 18s 143ms/step - loss: 154.7476 - age_output_loss: 108.8363 - gender_output_loss: 0.1741 - age_output_mean_absolute_error: 7.5118 - gender_output_binary_accuracy: 0.9295 - val_loss: 138.4728 - val_age_output_loss: 89.9846 - val_gender_output_loss: 0.2410 - val_age_output_mean_absolute_error: 6.5265 - val_gender_output_binary_accuracy: 0.8982
# Epoch 20/50
# 125/125 [==============================] - 18s 142ms/step - loss: 151.5582 - age_output_loss: 108.0286 - gender_output_loss: 0.1532 - age_output_mean_absolute_error: 7.5031 - gender_output_binary_accuracy: 0.9350 - val_loss: 151.1068 - val_age_output_loss: 99.6315 - val_gender_output_loss: 0.2806 - val_age_output_mean_absolute_error: 6.9558 - val_gender_output_binary_accuracy: 0.8800
# Epoch 21/50
# 125/125 [==============================] - 18s 143ms/step - loss: 150.5676 - age_output_loss: 106.9524 - gender_output_loss: 0.1590 - age_output_mean_absolute_error: 7.4373 - gender_output_binary_accuracy: 0.9325 - val_loss: 126.5277 - val_age_output_loss: 76.3677 - val_gender_output_loss: 0.2482 - val_age_output_mean_absolute_error: 6.0391 - val_gender_output_binary_accuracy: 0.8911
# Epoch 22/50
# 125/125 [==============================] - 18s 142ms/step - loss: 142.2567 - age_output_loss: 98.4442 - gender_output_loss: 0.1603 - age_output_mean_absolute_error: 7.1909 - gender_output_binary_accuracy: 0.9352 - val_loss: 130.5199 - val_age_output_loss: 75.3616 - val_gender_output_loss: 0.2863 - val_age_output_mean_absolute_error: 6.1379 - val_gender_output_binary_accuracy: 0.8780
# Epoch 23/50
# 125/125 [==============================] - 18s 142ms/step - loss: 147.0820 - age_output_loss: 105.7634 - gender_output_loss: 0.1414 - age_output_mean_absolute_error: 7.4046 - gender_output_binary_accuracy: 0.9430 - val_loss: 138.5982 - val_age_output_loss: 89.2503 - val_gender_output_loss: 0.2603 - val_age_output_mean_absolute_error: 6.5299 - val_gender_output_binary_accuracy: 0.8952
# Epoch 24/50
# 125/125 [==============================] - 18s 142ms/step - loss: 144.8862 - age_output_loss: 104.0791 - gender_output_loss: 0.1376 - age_output_mean_absolute_error: 7.2327 - gender_output_binary_accuracy: 0.9430 - val_loss: 126.2166 - val_age_output_loss: 76.0199 - val_gender_output_loss: 0.2586 - val_age_output_mean_absolute_error: 6.1391 - val_gender_output_binary_accuracy: 0.8901
# Epoch 25/50
# 125/125 [==============================] - 18s 142ms/step - loss: 140.3109 - age_output_loss: 99.8048 - gender_output_loss: 0.1348 - age_output_mean_absolute_error: 7.1783 - gender_output_binary_accuracy: 0.9445 - val_loss: 134.5631 - val_age_output_loss: 75.9000 - val_gender_output_loss: 0.2942 - val_age_output_mean_absolute_error: 6.3509 - val_gender_output_binary_accuracy: 0.8861
# Epoch 26/50
# 125/125 [==============================] - 18s 142ms/step - loss: 134.0253 - age_output_loss: 94.5570 - gender_output_loss: 0.1258 - age_output_mean_absolute_error: 7.0055 - gender_output_binary_accuracy: 0.9448 - val_loss: 138.4422 - val_age_output_loss: 93.5765 - val_gender_output_loss: 0.2403 - val_age_output_mean_absolute_error: 6.7647 - val_gender_output_binary_accuracy: 0.9042
# Epoch 27/50
# 125/125 [==============================] - 18s 142ms/step - loss: 133.9769 - age_output_loss: 95.6582 - gender_output_loss: 0.1166 - age_output_mean_absolute_error: 6.9925 - gender_output_binary_accuracy: 0.9520 - val_loss: 162.7168 - val_age_output_loss: 106.6813 - val_gender_output_loss: 0.3627 - val_age_output_mean_absolute_error: 7.0989 - val_gender_output_binary_accuracy: 0.8750
# Epoch 28/50
# 125/125 [==============================] - 18s 142ms/step - loss: 132.4906 - age_output_loss: 94.2590 - gender_output_loss: 0.1151 - age_output_mean_absolute_error: 6.9794 - gender_output_binary_accuracy: 0.9540 - val_loss: 129.0448 - val_age_output_loss: 73.4555 - val_gender_output_loss: 0.3064 - val_age_output_mean_absolute_error: 5.9416 - val_gender_output_binary_accuracy: 0.8861
# Epoch 29/50
# 125/125 [==============================] - 18s 143ms/step - loss: 131.8841 - age_output_loss: 94.4273 - gender_output_loss: 0.1101 - age_output_mean_absolute_error: 6.9708 - gender_output_binary_accuracy: 0.9575 - val_loss: 157.1391 - val_age_output_loss: 101.3869 - val_gender_output_loss: 0.2807 - val_age_output_mean_absolute_error: 7.2232 - val_gender_output_binary_accuracy: 0.8911

# %% [markdown]
# ## STEP4B: Draw the learning curve
# Draw four figures as follows
# 1.	The loss of the gender classification over the training and validation set
# 2.	The accuracy of the gender classification over the training and validation set
# 3.	The loss of the age estimation over the training and validation set
# 4.	The MAE of the age estimation over the training and validation set

# %%
#
# Add your code here
#
early_stopped_epoch_count = early_stop_cb.stopped_epoch+1
epochs = np.linspace(0, early_stopped_epoch_count, early_stopped_epoch_count)

fig, (gender_loss, gender_accuracy) = plt.subplots(2, sharex=True)
fig.suptitle("Gender Learning Curves")
fig.set_size_inches(12,8)

gender_loss.set_xlabel("Epoch")
gender_loss.set_ylabel("Gender Loss")
gender_loss.plot(epochs, modelB_history.history['gender_output_loss'], label='training')
gender_loss.plot(epochs, modelB_history.history['val_gender_output_loss'], label='validation')
gender_loss.legend()

gender_accuracy.set_xlabel("Epoch")
gender_accuracy.set_ylabel("Gender Accuracy")
gender_accuracy.plot(epochs, modelB_history.history['gender_output_binary_accuracy'], label='training')
gender_accuracy.plot(epochs, modelB_history.history['val_gender_output_binary_accuracy'], label='validation')
gender_accuracy.legend()

plt.show()

fig, (age_loss, age_mae) = plt.subplots(2, sharex=True)
fig.suptitle("Age Learning Curves")
fig.set_size_inches(12,8)

age_loss.set_xlabel("Epoch")
age_loss.set_ylabel("Age Loss")
age_loss.plot(epochs, modelB_history.history['age_output_loss'], label='training')
age_loss.plot(epochs, modelB_history.history['val_age_output_loss'], label='validation')
age_loss.legend()

age_mae.set_xlabel("Epoch")
age_mae.set_ylabel("Age Mean Absolute Error (MEA)")
age_mae.plot(epochs, modelB_history.history['age_output_mean_absolute_error'], label='training')
age_mae.plot(epochs, modelB_history.history['val_age_output_mean_absolute_error'], label='validation')
age_mae.legend()

plt.show()

# %% [markdown]
# ## STEP5: Evaluate the model on the test set
# I will add my test code here to test the two models you trained. The test set will not be available before your submission.
#
# The metrics for measuring the performance on the test set are:
# - age estimation: MAE (Mean Absolute Error)
# - gender classification: accuracy

# %%
#
# Don't add code in this cell when submitting this file
#
